# %% [markdown]
# ### Numbers

# %%
12345
# Out:
# 12345

# %%
my_number = 12345

# %%
type(my_number)
# Out:
# int

# %%
my_float = 3.14 
print(type(my_float))
print(my_float)
# Out:
# <class 'float'>
# 3.14

# %%
15 + 5
# Out:
# 20

# %%
14 - 3
# Out:
# 11

# %%
5 + 5.4
# Out:
# 10.4

# %%
15.0 + 2
# Out:
# 17.0

# %%
6 * 3.0
# Out:
# 18.0

# %%
6 / 8
# Out:
# 0.75

# %%
6 / 3 # Python, sonuç tam sayı olsa bile float şekilde yazdırır
# Out:
# 2.0

# %%
6 // 5 # bölümü verir
# Out:
# 1

# %%
8 % 5 # bölümden kalanı verir
# Out:
# 2

# %% [markdown]
# #### Another way to look at modulo

# %%
whole_part = int(5/3)
decimal_part = 5 / 3 - whole_part
print(decimal_part)
# Out:
# 0.6666666666666667

# %%
whole_remainder = decimal_part*3
print(whole_remainder)
# Out:
# 2.0

# %%
int(3.45)
# Out:
# 3

# %%
float(14)
# Out:
# 14.0

# %%
round(3.1415, 2)
# Out:
# 3.14

# %%
print(type(round(3.1415)))
# Out:
# <class 'int'>

# %%
import math
print(math.floor(3.99999))
# Out:
# 3

# %%
2 + 3 * 4
# Out:
# 14

# %%
(2 + 3) * 4
# Out:
# 20

# %%
0.1 * 3
# Out:
# 0.30000000000000004

# %%
from decimal import Decimal

# %%
Decimal('0.1') * 3
# Out:
# Decimal('0.3')

# %%
import random 
random.randint(0, 99)
# Out:
# 89

# %% [markdown]
# ### Strings

# %%
my_string = 'my text is "important"' 
print(my_string)
# Out:
# my text is "important"

# %%
long_string = '''
###
 text
    example
'''
print(long_string)
# Out:
# ###
#  text
#     example

# %%
str(my_number)
print(type(my_number))
# Out:
# <class 'int'>

# %%
print(my_string)
print(my_string[2])
print(len(my_string[2]))
# Out:
# my text is "important"
#
# 1

# %%
len(my_string[-1])
# Out:
# 1

# %% [markdown]
# Slice
# <str>[<start>:stop:<step>]

# %%
my_string[1:4]
# Out:
# 'y t'

# %%
my_string[:4]
# Out:
# 'my t'

# %%
my_string[1:]
# Out:
# 'y text is "important"'

# %%
my_string[::-2]
# Out:
# '"ntom"s xty'

# %%
my_string.split() # boşluklara göre kelimeleri ayırır
# Out:
# ['my', 'text', 'is', '"important"']

# %%
animals = ["cat", "dog", "horse"]

# %%
", ".join(animals)
# Out:
# 'cat, dog, horse'

# %%
for item in my_string:
    print(item)
# Out:
# m
# y
#
# t
# e
# x
# t
#
# i
# s
#
# "
# i
# m
# p
# o
# r
# t
# a
# n
# t
# "

# %% [markdown]
# ### fstrings

# %%
name="Kemal"
age=33
print(f"My name is {name} and my age is {age}")
# Out:
# My name is Kemal and my age is 33

# %%
import datetime

# %%
today = datetime.datetime.today()
print(today)
# Out:
# 2023-11-26 13:46:17.404967

# %%
print(f"{today: %d %B %Y}")
# Out:
#  26 November 2023

# %% [markdown]
# ### Boolean

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
my_variable = 0 
if my_variable:
    print("yes it is true")
else:
    print("no it is false")
# Out:
# no it is false

# %%
my_variable is True
# Out:
# False

# %% [markdown]
# > **02.12.2023**

# %% [markdown]
# ### Boolean Operators

# %% [markdown]
# and, or, not

# %%
bool(1) and bool(0)
# Out:
# False

# %%
result = 1 and 0
bool(result)
# Out:
# False

# %%
False or True
# Out:
# True

# %%
print(not True and False)
print(not (True and False))
# Out:
# False
# True

# %%
1 == True
# Out:
# True

# %%
0 == True
# Out:
# False

# %%
first_number = 10
second_number = 5

if first_number > second_number:
    print(f"{first_number} is greater than {second_number}")
# Out:
# 10 is greater than 5

# %%
first_number = 10
second_number = 25

if first_number > second_number:
    print(f"{first_number} is greater than {second_number}")
else:
    print(f"{second_number} is greater than {first_number}")
# Out:
# 25 is greater than 10

# %%
first_number = 10
second_number = 10

if first_number > second_number:
    print(f"{first_number} is greater than {second_number}")
elif first_number == second_number:
    print(f"{second_number} is equal with {first_number}")
else:
    print(f"{second_number} is greater than {first_number}")
# Out:
# 10 is equal with 10

# %%
test_score = 80
age = 18
# age between 16-18 intern-driver, score 80 or above, intern-driver
# age above 18, score 80 or above, driver
# age between 16-18, score 60-80, supervised-intern driver
# age above 18, score 60-80, supervised-driver

def driver_status(age, test_score):
    if 16<=age<18 and 80<=test_score:
        print("intern-driver")
    elif 18<=age and 80<=test_score:
        print("driver")
    elif 16<=age<18 and 60<=test_score<80:
        print("supervised-intern-driver")
    elif 18<=age and 60<=test_score<80:
        print("supervised-driver")
    else:
        print("no lisence driver")

driver_status(16, 80)
# Out:
# intern-driver

# %%
def driver_status2(age, test_score):
    if test_score >= 80:
        if 18 > age >= 16:
            return "intern-driver"
        elif age >= 18: 
            return "driver"
    elif 80 > test_score >= 60:
        if 18 > age >=16:
            return "supervised-intern-driver"
        elif age >=18:
            return "supervised-driver"
    return "Unlicenced"

# %%
def buzz_func(number):
    return "Buzz!" if number % 2 == 0 else str(number)

# %%
my_number=12
buzz_func(my_number)
# Out:
# 'Buzz!'

# %% [markdown]
# ### String Methods

# %%
test_string = "Ada Lovelace Academy had started!     "

# %%
test_string.lower()
# Out:
# 'ada lovelace academy had started!     '

# %%
test_string.upper()
# Out:
# 'ADA LOVELACE ACADEMY HAD STARTED!     '

# %%
test_string.strip()
# Out:
# 'Ada Lovelace Academy had started!'

# %%
test_string = "Ada Lovelace Academy had started!"
test_string.strip('!')
# Out:
# 'Ada Lovelace Academy had started'

# %%
test_string.endswith('!')
# Out:
# True

# %%
test_string.replace('!', '.')
# Out:
# 'Ada Lovelace Academy had started.'

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %% [markdown]
# ### Comparisons

# %%
15 != 10
# Out:
# True

# %%
"Ada" == "Lovelace"
# Out:
# False

# %%
15 is not my_number
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\leyla\AppData\Local\Temp\ipykernel_15032\3648682713.py:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   15 is not my_number
# True

# %%
my_list = [1, 2, 3]
print(3 not in my_list)
print(1 in my_list)
# Out:
# False

# %% [markdown]
# ### List
# > Mutable

# %%
empty_list = []
print(empty_list)
# Out:
# []

# %%
example_list = [1, "string", [1, 2, 3]]
print(example_list)
# Out:
# [1, 'string', [1, 2, 3]]

# %%
test_list = list()
print(test_list)
# Out:
# []

# %%
example_list = list(1, "string", [1, 2, 3])
print(example_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\AdaLovelaceAkademi\AdaLovelaceAcademy\1-python-data-types.ipynb Cell 88 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/AdaLovelaceAkademi/AdaLovelaceAcademy/1-python-data-types.ipynb#Y165sZmlsZQ%3D%3D?line=0'>1</a> example_list = list(1, "string", [1, 2, 3])
#       <a href='vscode-notebook-cell:/d%3A/AdaLovelaceAkademi/AdaLovelaceAcademy/1-python-data-types.ipynb#Y165sZmlsZQ%3D%3D?line=1'>2</a> print(example_list)
#
# TypeError: list expected at most 1 argument, got 3

# %%
example_list = list(1)
print(example_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\AdaLovelaceAkademi\AdaLovelaceAcademy\1-python-data-types.ipynb Cell 89 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/AdaLovelaceAkademi/AdaLovelaceAcademy/1-python-data-types.ipynb#Y201sZmlsZQ%3D%3D?line=0'>1</a> example_list = list(1)
#       <a href='vscode-notebook-cell:/d%3A/AdaLovelaceAkademi/AdaLovelaceAcademy/1-python-data-types.ipynb#Y201sZmlsZQ%3D%3D?line=1'>2</a> print(example_list)
#
# TypeError: 'int' object is not iterable

# %%
example_list = list("string")
literal_list = ["string"]
print(example_list)
print(literal_list)
# Out:
# ['s', 't', 'r', 'i', 'n', 'g']
# ['string']

# %%
example_list = [1, "academy", [1, 2, 3]]
example_list[0]
# Out:
# 1

# %%
example_list[-1]
# Out:
# [1, 2, 3]

# %%
example_list[:2]
# Out:
# [1, 'academy']

# %%
colors = ["yellow", "green", "red", "blue", "purple"]

for color in colors:
    print(color)
# Out:
# yellow
# green
# red
# blue
# purple

# %%
for index, color in enumerate(colors):
    print(f"{index}: {color}")
# Out:
# 0: yellow
# 1: green
# 2: red
# 3: blue
# 4: purple

# %%
cubes_to_1000 = []

for number in range(0, 11, 1):
    cubes_to_1000.append(number**3)

cubes_to_1000
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %%
new_colors = colors
print(new_colors)
# Out:
# ['yellow', 'green', 'red', 'blue', 'purple']

# %%
new_colors.append("orange")
print(new_colors)
# Out:
# ['yellow', 'green', 'red', 'blue', 'purple', 'orange']

# %%
print(colors)
# Out:
# ['yellow', 'green', 'red', 'blue', 'purple', 'orange']

# %%
colors.pop() # delete last element
# Out:
# 'orange'

# %%
print(colors)
# Out:
# ['yellow', 'green', 'red', 'blue', 'purple']

# %%
newest_colors = colors.copy()
print(newest_colors)
# Out:
# ['yellow', 'green', 'red', 'blue', 'purple']

# %%
newest_colors.append("black")
print(newest_colors)
print(colors)
# Out:
# ['yellow', 'green', 'red', 'blue', 'purple', 'black']
# ['yellow', 'green', 'red', 'blue', 'purple']

# %%
newest_colors.insert(0, "gray")
print(newest_colors)
# Out:
# ['gray', 'yellow', 'green', 'red', 'blue', 'purple', 'black']

# %%
# extend: add two list together

# %%
newest_colors.remove('yellow')
newest_colors
# Out:
# ['gray', 'green', 'red', 'blue', 'purple', 'black']

# %%
newest_colors.remove('cyan')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\AdaLovelaceAkademi\AdaLovelaceAcademy\1-python-data-types.ipynb Cell 107 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/AdaLovelaceAkademi/AdaLovelaceAcademy/1-python-data-types.ipynb#Y223sZmlsZQ%3D%3D?line=0'>1</a> newest_colors.remove('cyan')
#
# ValueError: list.remove(x): x not in list

# %%
# reverse:

# %%
colros = ['yellow', 'green', 'red', 'blue', 'purple']
colors.sort(reverse=True)
colors
# Out:
# ['yellow', 'red', 'purple', 'green', 'blue']

# %%
colors.index("red")
# Out:
# 1

# %% [markdown]
# ### Tuples & Dictionaries

# %%
my_tuple = tuple()

# %%
my_tuple = tuple([10])

# %%
print(my_tuple)
# Out:
# (10,)

# %%
my_tuple = tuple("Lovelace")
print(my_tuple)
# Out:
# ('L', 'o', 'v', 'e', 'l', 'a', 'c', 'e')

# %%
my_tuple = tuple([10, "Ada", "Lovelace", 11])
print(my_tuple)
# Out:
# (10, 'Ada', 'Lovelace', 11)

# %%
# dictionary
animal_colors = {
    "cat": "yellow",
    "dog": "black",
    "horse": "brown"
}

# %%
animal_colors_tuple = tuple(animal_colors)
print(animal_colors_tuple)
# Out:
# ('cat', 'dog', 'horse')

# %%
animal_colors_tuple_2 = tuple(animal_colors.items())
animal_colors_tuple_2
# Out:
# (('cat', 'yellow'), ('dog', 'black'), ('horse', 'brown'))

# %%
my_new_tuple = ("ada") # str. For tuple, ("ada", ) 
print(type(my_new_tuple))
# Out:
# <class 'tuple'>

# %%
my_new_tuple = "ada", "lovelace"
print(my_new_tuple)
# Out:
# ('ada', 'lovelace')

# %%
my_new_tuple[0]
# Out:
# 'ada'

# %%
animals = dict([('cat', 'yellow'), ('dog', 'black'), ('horse', 'brown')])
print(animals)
# Out:
# {'cat': 'yellow', 'dog': 'black', 'horse': 'brown'}

# %%
animals = {
    "cat":{
        "color": "yellow",
        "weight": "5.1"
    },
    "dog": "black",
    "horse": "brown"
}

# %%
animals["dog"]
# Out:
# 'black'

# %%
animals["dolphin"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\AdaLovelaceAkademi\AdaLovelaceAcademy\1-python-data-types.ipynb Cell 126 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/AdaLovelaceAkademi/AdaLovelaceAcademy/1-python-data-types.ipynb#Y251sZmlsZQ%3D%3D?line=0'>1</a> animals["dolphin"]
#
# KeyError: 'dolphin'

# %%
animals["cat"]
# Out:
# {'color': 'yellow', 'weight': '5.1'}

# %%
animals["cat"]["color"]
# Out:
# 'yellow'

# %%
animals.get("cat")
# Out:
# {'color': 'yellow', 'weight': '5.1'}

# %%
animals.get("bear")

# %%
animals["bear"] = "brown"

# %%
print(animals)
# Out:
# {'cat': {'color': 'yellow', 'weight': '5.1'}, 'dog': 'black', 'horse': 'brown', 'bear': 'brown'}

# %%
animals.pop("horse")
# Out:
# 'brown'

# %%
animals
# Out:
# {'cat': {'color': 'yellow', 'weight': '5.1'}, 'dog': 'black', 'bear': 'brown'}

# %%
# del

# %%
animal_colors = {
    "cat": "yellow",
    "dog": "black",
    "horse": "brown"
}

# %%
for animal, color in animal_colors.items():
    print(f"{animal} is {color}")
# Out:
# cat is yellow
# dog is black
# horse is brown

# %% [markdown]
# ### Sets

# %%
# sets are mutable 
# frozensets are immutable

# iteration
# membership (in, not in) # It is not costly to check if there is an element in the sets.
# len()
# copy()

# %%
## sets do not support!:
### indexing
### ordering, sorting
### slicing
### concat +

# %%
my_set = {"ada"}
print(type(my_set))
# Out:
# <class 'set'>

# %%
animal_set = set(animal_colors)
print(animal_set)
# Out:
# {'horse', 'dog', 'cat'}

# %%
animal_colors = {
    "cat": "yellow",
    "dog": "black",
    "horse": "brown",
    "bear": "brown"
}

animal_set = set(animal_colors.values())
print(animal_set)
# Out:
# {'black', 'brown', 'yellow'}

# %%
numbers = [1, 1, 1, 2, 2, 2, 3, 4, 4, 5, 15]

calculated_numbers = {number**2 for number in numbers if number % 3 == 0}
calculated_numbers
# Out:
# {9, 225}

# %%
def calc_num(numberss):
    sonuc = []
    for number in numberss:
        if (number**2) % 3 == 0:
            sonuc.append(number**2)
    return set(sonuc)

calc_num(numbers)
# Out:
# {9, 225}

# %%
elements_string = set("lovelace")
print(elements_string)
# Out:
# {'a', 'e', 'c', 'v', 'o', 'l'}

# %%
birds = {"crow", "sparrow", "eagle", "chicken", "albatross"}

animals = {'chicken': 'white',
           'sparrow': 'grey',
           'eagle': 'brown and white',
           'albatross': 'grey and white',
           'crow': 'black',
           'elephant': 'grey', 
           'dog': 'rust',
           'cow': 'black and white',
           'tiger': 'orange and black',
           'cat': 'grey',
           'squirrel': 'black'}

# %%
birds.isdisjoint(animals)
# Out:
# False

# %%
birds.issubset(animals)
# Out:
# True

# %%
set(animals).issuperset(birds)
# Out:
# True
